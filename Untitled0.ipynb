# %% [markdown]
# <a href="https://colab.research.google.com/github/TACK2427/TACK2427/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scratchattach
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=bc5074c6af64ef168b7a701bb92463ca6f8472d28e5fbd286facd5c177557af4
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4

# %%
#各種モジュールをインポート（拡張機能を追加するイメージ）
import scratchattach as scratch3
import time

#セッションIDを決める
sessionID = ".eJxVj0lPwzAUhP9LzjR4Sbz0VmhBiBNQcegl8vLSOItdNa5Qi_jv2FIuvc7M-97Mb3GZ4ezVBMW62G-e30lFePFQxDCAT5IVmHDCWsoRrlohFdNU1IYyhIyUFNbueviS36_yY7W99T16sbtpqt4O49iIhBnD0fmVOyUSrmlJEC8xliVGdTIbdYldk_83zuYEwrhiVMjk2V75Y2iim-AWfC63mZ163IfhGu5POzV3yeZCWk1IImjBGdZCEKa0RtQyAwhasG3qq6u8DeZoQhhcxv6E8wD2HqmVSetzpayBj86o6IIvF2MuP-E0LuLTEv77B68paCs:1rKtUY:vhM6DfbjyUR_FV5iG_1g-bDp6sw"

#Scratchにログイン（正確には少し違います）
session = scratch3.Session(sessionID, username="TACK2427")

#クラウド変数に接続（下の数字を作った作品のプロジェクトIDに！）
connection = session.connect_cloud(project_id=944402218)
print("クラウド変数に接続しました")

while True: #無限ループ
  num = str(int(time.time())) #設定する整数を指定（今は1970年からの秒数）
  connection.set_var("last_access", num) #クラウド変数を設定
  print(f"セット完了 {num}")
  time.sleep(0.5) #5秒待つ
# Out:
# Streaming output truncated to the last 5000 lines.
# セット完了 1704531380
# セット完了 1704531380
# セット完了 1704531381
# セット完了 1704531381
# セット完了 1704531382
# セット完了 1704531382
# セット完了 1704531383
# セット完了 1704531383
# セット完了 1704531384
# セット完了 1704531384
# セット完了 1704531385
# セット完了 1704531386
# セット完了 1704531386
# セット完了 1704531387
# セット完了 1704531387
# セット完了 1704531388
# セット完了 1704531388
# セット完了 1704531389
# セット完了 1704531389
# セット完了 1704531390
# セット完了 1704531390
# セット完了 1704531391
# セット完了 1704531391
# セット完了 1704531392
# セット完了 1704531392
# セット完了 1704531393
# セット完了 1704531393
# セット完了 1704531394
# セット完了 1704531394
# セット完了 1704531395
# セット完了 1704531395
# セット完了 1704531396
# セット完了 1704531396
# セット完了 1704531397
# セット完了 1704531397
# セット完了 1704531398
# セット完了 1704531398
# セット完了 1704531399
# セット完了 1704531399
# セット完了 1704531400
# セット完了 1704531400
# セット完了 1704531401
# セット完了 1704531401
# セット完了 1704531402
# セット完了 1704531402
# セット完了 1704531403
# セット完了 1704531403
# セット完了 1704531404
# セット完了 1704531404
# ...

# %%
#各種モジュールをインポート（拡張機能を追加するイメージ）
import scratchattach as scratch3
import time

#セッションIDを決める
sessionID = ".eJxVj0lPwzAUhP9LzjR4Sbz0VmhBiBNQcegl8vLSOItdNa5Qi_jv2FIuvc7M-97Mb3GZ4ezVBMW62G-e30lFePFQxDCAT5IVmHDCWsoRrlohFdNU1IYyhIyUFNbueviS36_yY7W99T16sbtpqt4O49iIhBnD0fmVOyUSrmlJEC8xliVGdTIbdYldk_83zuYEwrhiVMjk2V75Y2iim-AWfC63mZ163IfhGu5POzV3yeZCWk1IImjBGdZCEKa0RtQyAwhasG3qq6u8DeZoQhhcxv6E8wD2HqmVSetzpayBj86o6IIvF2MuP-E0LuLTEv77B68paCs:1rKtUY:vhM6DfbjyUR_FV5iG_1g-bDp6sw"

#Scratchにログイン（正確には少し違います）
session = scratch3.Session(sessionID, username="TACK2427")

#クラウド変数に接続（下の数字を作った作品のプロジェクトIDに！）
connection = session.connect_cloud(project_id=944402218)
print("クラウド変数に接続しました")

while True: #無限ループ
  num = str(int(time.time())) #設定する整数を指定（今は1970年からの秒数）
  connection.set_var("test", num) #クラウド変数を設定
  print(f"セット完了 {num}")
  time.sleep(0.5) #5秒待つ
